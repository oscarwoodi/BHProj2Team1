# %% [markdown]
# # Loading Data & Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_excel('Data/Time Series Data.xlsx',index_col='Day')
test_bed=pd.read_excel('Data/Test Bed.xlsx',index_col='Day')

# %% [markdown]
# # Data Exploration

# %%
corr_table=df.corr()

# %%
# finding correlations
plt.figure(figsize=(16, 6))
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True)
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# finding largest correlations
cor = df.corr()
cor[(cor > 0.9) & (cor < 1)]
# Out:
#            Series 1  Series 2  Series 3  Series 4  Series 5  Series 6  \
# Series 1        NaN  0.940150       NaN  0.912122       NaN       NaN
# Series 2   0.940150       NaN       NaN       NaN       NaN       NaN
# Series 3        NaN       NaN       NaN       NaN       NaN       NaN
# Series 4   0.912122       NaN       NaN       NaN  0.970505       NaN
# Series 5        NaN       NaN       NaN  0.970505       NaN       NaN
# Series 6        NaN       NaN       NaN       NaN       NaN       NaN
# Series 7        NaN       NaN  0.944275       NaN       NaN       NaN
# Series 8   0.964281  0.951644       NaN  0.958921  0.939942       NaN
# Series 9   0.959751  0.950948       NaN       NaN       NaN       NaN
# Series 10       NaN       NaN       NaN       NaN       NaN       NaN
# Series 11  0.927526       NaN       NaN  0.961506  0.939797       NaN
# Series 12  0.957771  0.975996       NaN       NaN       NaN       NaN
# Series 13  0.917373  0.984018       NaN       NaN       NaN       NaN
# Series 14       NaN  0.931092       NaN       NaN       NaN       NaN
# Series 15  0.906599       NaN       NaN  0.950761  0.944466       NaN
# Series 16       NaN       NaN       NaN  0.937287  0.915815       NaN
# Series 17  0.926492       NaN       NaN       NaN       NaN       NaN
# Series 18       NaN       NaN       NaN       NaN       NaN       NaN
# Series 19       NaN       NaN       NaN       NaN       NaN       NaN
# Series 20       NaN       NaN       NaN       NaN       NaN       NaN
# Series 21       NaN       NaN       NaN       NaN       NaN       NaN
# Series 22       NaN       NaN       NaN       NaN       NaN       NaN
# Series 23       NaN       NaN       NaN       NaN       NaN       NaN
# Series 24       NaN       NaN       NaN       NaN       NaN       NaN
# Series 25  0.972865  0.952508  0.916312  0.957274  0.940522       NaN
# Series 26  0.958556  0.923071  0.914526  0.974444  0.958400       NaN
# Series 27  0.966878  0.948235  0.919681  0.955998  0.928581       NaN
# Series 28       NaN       NaN       NaN       NaN       NaN       NaN
# Series 29       NaN       NaN       NaN       NaN       NaN       NaN
#
#            Series 7  Series 8  Series 9  Series 10  ...  Series 20  Series 21  \
# Series 1        NaN  0.964281  0.959751        NaN  ...        NaN        NaN
# Series 2        NaN  0.951644  0.950948        NaN  ...        NaN        NaN
# Series 3   0.944275       NaN       NaN        NaN  ...        NaN        NaN
# Series 4        NaN  0.958921       NaN        NaN  ...        NaN        NaN
# Series 5        NaN  0.939942       NaN        NaN  ...        NaN        NaN
# Series 6        NaN       NaN       NaN        NaN  ...        NaN        NaN
# Series 7        NaN       NaN       NaN        NaN  ...        NaN        NaN
# Series 8        NaN       NaN  0.961210        NaN  ...        NaN        NaN
# Series 9        NaN  0.961210       NaN        NaN  ...        NaN        NaN
# Series 10       NaN       NaN       NaN        NaN  ...        NaN        NaN
# Series 11       NaN  0.956175  0.907872        NaN  ...        NaN        NaN
# Series 12       NaN  0.953015  0.957408        NaN  ...        NaN        NaN
# Series 13       NaN  0.927447  0.943579        NaN  ...        NaN        NaN
# Series 14       NaN       NaN       NaN        NaN  ...        NaN        NaN
# Series 15       NaN  0.947759  0.905337        NaN  ...        NaN        NaN
# Series 16       NaN  0.918353       NaN        NaN  ...        NaN        NaN
# Series 17       NaN  0.917566  0.901563        NaN  ...        NaN        NaN
# Series 18       NaN       NaN       NaN        NaN  ...        NaN        NaN
# Series 19       NaN       NaN       NaN        NaN  ...        NaN        NaN
# Series 20       NaN       NaN       NaN        NaN  ...        NaN        NaN
# Series 21       NaN       NaN       NaN        NaN  ...        NaN        NaN
# Series 22       NaN       NaN       NaN        NaN  ...        NaN        NaN
# Series 23       NaN       NaN       NaN        NaN  ...        NaN        NaN
# Series 24       NaN       NaN       NaN        NaN  ...        NaN        NaN
# Series 25       NaN  0.989185  0.970815        NaN  ...        NaN        NaN
# Series 26       NaN  0.984121  0.955839        NaN  ...        NaN        NaN
# Series 27       NaN  0.984428  0.966816        NaN  ...        NaN        NaN
# Series 28       NaN       NaN       NaN        NaN  ...        NaN        NaN
# Series 29       NaN       NaN       NaN        NaN  ...        NaN        NaN
#
#            Series 22  Series 23  Series 24  Series 25  Series 26  Series 27  \
# Series 1         NaN        NaN        NaN   0.972865   0.958556   0.966878
# Series 2         NaN        NaN        NaN   0.952508   0.923071   0.948235
# Series 3         NaN        NaN        NaN   0.916312   0.914526   0.919681
# Series 4         NaN        NaN        NaN   0.957274   0.974444   0.955998
# Series 5         NaN        NaN        NaN   0.940522   0.958400   0.928581
# Series 6         NaN        NaN        NaN        NaN        NaN        NaN
# Series 7         NaN        NaN        NaN        NaN        NaN        NaN
# Series 8         NaN        NaN        NaN   0.989185   0.984121   0.984428
# Series 9         NaN        NaN        NaN   0.970815   0.955839   0.966816
# Series 10        NaN        NaN        NaN        NaN        NaN        NaN
# Series 11        NaN        NaN        NaN   0.946030   0.958037   0.951686
# Series 12        NaN        NaN        NaN   0.952808   0.928363   0.949088
# Series 13        NaN        NaN        NaN   0.940631   0.908384   0.933325
# Series 14        NaN        NaN        NaN        NaN        NaN        NaN
# Series 15        NaN        NaN        NaN   0.954343   0.966100   0.957749
# Series 16        NaN        NaN        NaN   0.911270   0.922141   0.915497
# Series 17        NaN        NaN        NaN   0.921625   0.923517   0.939568
# Series 18        NaN        NaN        NaN        NaN        NaN        NaN
# Series 19        NaN        NaN        NaN        NaN        NaN        NaN
# Series 20        NaN        NaN        NaN        NaN        NaN        NaN
# Series 21        NaN        NaN        NaN        NaN        NaN        NaN
# Series 22        NaN        NaN        NaN        NaN        NaN        NaN
# Series 23        NaN        NaN        NaN        NaN        NaN        NaN
# Series 24        NaN        NaN        NaN        NaN        NaN        NaN
# Series 25        NaN        NaN        NaN        NaN   0.994745   0.995261
# Series 26        NaN        NaN        NaN   0.994745        NaN   0.993495
# Series 27        NaN        NaN        NaN   0.995261   0.993495        NaN
# Series 28        NaN        NaN        NaN        NaN        NaN        NaN
# Series 29        NaN        NaN        NaN        NaN        NaN        NaN
#
#            Series 28  Series 29
# Series 1         NaN        NaN
# Series 2         NaN        NaN
# Series 3         NaN        NaN
# Series 4         NaN        NaN
# Series 5         NaN        NaN
# Series 6         NaN        NaN
# Series 7         NaN        NaN
# Series 8         NaN        NaN
# Series 9         NaN        NaN
# Series 10        NaN        NaN
# Series 11        NaN        NaN
# Series 12        NaN        NaN
# Series 13        NaN        NaN
# Series 14        NaN        NaN
# Series 15        NaN        NaN
# Series 16        NaN        NaN
# Series 17        NaN        NaN
# Series 18        NaN        NaN
# Series 19        NaN        NaN
# Series 20        NaN        NaN
# Series 21        NaN        NaN
# Series 22        NaN        NaN
# Series 23        NaN        NaN
# Series 24        NaN        NaN
# Series 25        NaN        NaN
# Series 26        NaN        NaN
# Series 27        NaN        NaN
# Series 28        NaN        NaN
# Series 29        NaN        NaN
#
# [29 rows x 29 columns]

# %% [markdown]
# # Plots and correlation

# %%
# plotting log returns
fig, ax = plt.subplots()
fig.set_figwidth(15)
fig.set_figheight(10)
ax.plot(np.log(df)-np.log(100))
ax.legend(df)
plt.show()
