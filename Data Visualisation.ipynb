# %%
# imports 
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import math
import seaborn as sns

# %%
# data import 
df = pd.read_excel('Time Series Data.xlsx', index_col = 'Day')
df.head()
# Out:
#        Series 1    Series 2    Series 3    Series 4    Series 5    Series 6  \
# Day
# 0    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 1    100.172920  100.589993  103.823464   98.644063   99.750482  106.614321
# 2     98.579911   98.767737  107.058757   97.936942   99.220660  110.602917
# 3     98.397809   97.087379  107.352843  100.000000   99.251805  113.424191
# 4     99.051233   99.716206  105.587978   99.703996   99.407530  113.715275
#
#        Series 7    Series 8    Series 9   Series 10  ...   Series 20  \
# Day                                                  ...
# 0    100.000000  100.000000  100.000000  100.000000  ...  100.000000
# 1    101.767999  100.732626   99.952576  100.227093  ...  101.568951
# 2    100.681776  100.383846   99.617067  100.246064  ...  106.193229
# 3    102.651998  101.569981   98.659381  101.230321  ...  106.936416
# 4    100.710685  101.081407   99.760755  101.040888  ...  107.018993
#
#       Series 21   Series 22   Series 23   Series 24   Series 25   Series 26  \
# Day
# 0    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 1     99.730607   99.673906   99.409461   99.113705  100.012563  100.311565
# 2    101.541426   99.977798   99.577298   99.783831   99.682467  100.366287
# 3    100.938414   99.278429   99.055138  100.875486   99.637414  100.767880
# 4    101.448655   99.979185   99.602163  100.162127  100.379047  101.058262
#
#       Series 27   Series 28   Series 29
# Day
# 0    100.000000  100.000000  100.000000
# 1     99.887188   96.556886   97.922078
# 2     99.902872   95.608782  100.000000
# 3    100.216365   95.109780  100.000000
# 4    100.323414   90.469062   99.480519
#
# [5 rows x 29 columns]

# %%
# plotting log returns
fig, ax = plt.subplots()
fig.set_figwidth(15)
fig.set_figheight(10)
ax.plot(np.log(df)-np.log(100))
ax.legend(df)
plt.show()

# %%
# finding correlations
plt.figure(figsize=(16, 6))
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True)
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# finding largest correlations
cor = df.corr()
cor[(cor > 0.9) & (cor < 1)]
# Out:
#           Series 1  Series 2  Series 3  Series 4  Series 5  Series 6  \
# Series 1       NaN   0.94015       NaN  0.912122       NaN       NaN
# Series 2  0.940150       NaN       NaN       NaN       NaN       NaN
# Series 3       NaN       NaN       NaN       NaN       NaN       NaN
# Series 4  0.912122       NaN       NaN       NaN  0.970505       NaN
# Series 5       NaN       NaN       NaN  0.970505       NaN       NaN
#
#           Series 7  Series 8  Series 9  Series 10  ...  Series 20  Series 21  \
# Series 1       NaN  0.964281  0.959751        NaN  ...        NaN        NaN
# Series 2       NaN  0.951644  0.950948        NaN  ...        NaN        NaN
# Series 3  0.944275       NaN       NaN        NaN  ...        NaN        NaN
# Series 4       NaN  0.958921       NaN        NaN  ...        NaN        NaN
# Series 5       NaN  0.939942       NaN        NaN  ...        NaN        NaN
#
#           Series 22  Series 23  Series 24  Series 25  Series 26  Series 27  \
# Series 1        NaN        NaN        NaN   0.972865   0.958556   0.966878
# Series 2        NaN        NaN        NaN   0.952508   0.923071   0.948235
# Series 3        NaN        NaN        NaN   0.916312   0.914526   0.919681
# Series 4        NaN        NaN        NaN   0.957274   0.974444   0.955998
# Series 5        NaN        NaN        NaN   0.940522   0.958400   0.928581
#
#           Series 28  Series 29
# Series 1        NaN        NaN
# Series 2        NaN        NaN
# Series 3        NaN        NaN
# Series 4        NaN        NaN
# Series 5        NaN        NaN
#
# [5 rows x 29 columns]

# %%
# identifying assets
vix = df['Series 28']
vix.plot()
# Out:
# <AxesSubplot:xlabel='Day'>
